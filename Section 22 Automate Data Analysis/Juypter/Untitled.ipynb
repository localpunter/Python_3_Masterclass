# %%
import pandas

# %%
dtxt = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.txt")

# %%
dtxt
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dtxt2 = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees2.txt", delimiter = "|")

# %%
dtxt2
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9      Test     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv", header = None)

# %%
dcsv
# Out:
#      0          1         2           3           4                    5  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          6                7
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv", header = None, names = ["A","B", "C", "D", "E", "F", "G", "H"])
dcsv
# Out:
#      A          B         C           D           E                    F  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          G                H
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv", header = None, prefix = "COL")
dcsv
# Out:
#    COL0       COL1      COL2        COL3        COL4                 COL5  \
# 0    ID  FirstName  LastName  Department       Phone              Address
# 1     1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2     2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3     3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4     4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5     5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6     6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7     7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8     8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9     9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10   10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#       COL6             COL7
# 0   Salary           Skills
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID", inplace = True)
dcsv
# Out:
#    FirstName  LastName Department       Phone              Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 2       Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 3        Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 6       Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 7    Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 8     Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 9        Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 1      Online Sales
# 2        Networking
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# ...

# %%
dcsv.set_index("Address", inplace = True)
dcsv
# Out:
#                     FirstName  LastName Department       Phone  Salary  \
# Address
# 1st Address, Miami       Luke   Phillip      Sales  1234567890   52000
# 2nd Address, Miami       Jack    Darren         IT  1234567891   52200
# 3rd Address, Miami        Ken      Wood         IT  1234567892   58000
# 4th Address, Miami       John    Wilson  Marketing  1234567893   58700
# 5th Address, Miami      Emily    Larson  Marketing  1234567894   60000
# 6th Address, Miami       Anna  Sullivan      Sales  1234567895   54000
# 7th Address, Miami    Richard     Smith  Logistics  1234567896   56000
# 8th Address, Miami     Ronnie     Moore      Sales  1234567897   49000
# 9th Address, Miami        Ron     Drake         IT  1234567898   53000
# 10th Address, Miami     Wayne    Barker  Logistics  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# 3rd Address, Miami      Python, Java
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.shape
# Out:
# (10, 8)

# %%
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv", skiprows = 4)
dcsv
# Out:
#     4     John    Wilson  Marketing  1234567893   4th Address, Miami  58700  \
# 0   5    Emily    Larson  Marketing  1234567894   5th Address, Miami  60000
# 1   6     Anna  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 2   7  Richard     Smith  Logistics  1234567896   7th Address, Miami  56000
# 3   8   Ronnie     Moore      Sales  1234567897   8th Address, Miami  49000
# 4   9      Ron     Drake         IT  1234567898   9th Address, Miami  53000
# 5  10    Wayne    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#       Facebook Ads
# 0    Instagram Ads
# 1  In-Person Sales
# 2  Warehouse Mgmt.
# 3     Online Sales
# 4    Linux Servers
# 5  Product Loading

# %%
dcsv = pandas.read_csv("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.csv", nrows = 5)
dcsv
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 3   4      John   Wilson  Marketing  1234567893  4th Address, Miami   58700
# 4   5     Emily   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#           Skills
# 0   Online Sales
# 1     Networking
# 2   Python, Java
# 3   Facebook Ads
# 4  Instagram Ads

# %%
djson = pandas.read_json("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.json")
djson
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dexcel = pandas.read_excel("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.xlsx")
dexcel
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
HT = pandas.read_excel("C:\\Users\\local_4nmktoc\\Documents\\Alan_HT.xlsx")
HT
# Out:
#          Date  Weight (kg) Stones & Pound  \
# 0  2019-03-20         77.8   12 st 4 lbs
# 1  2019-03-21         77.6   12 st 3 lbs
# 2  2019-03-22         76.7   12 st 1 lbs
# 3  2019-03-23          NaN            NaN
# 4  2019-03-24         77.6   12 st 3 lbs
# 5  2019-03-25         77.6   12 st 3 lbs
# 6  2019-03-26         76.8   12 st 1 lbs
# 7  2019-03-27         76.1  11 st 14 lbs
# 8  2019-03-28         76.4   12 st 0 lbs
# 9  2019-03-29         76.2  11 st 14 lbs
# 10 2019-03-30         77.6   12 st 3 lbs
# 11 2019-03-31          NaN            NaN
# 12 2019-04-01         76.6   12 st 1 lbs
# 13 2019-04-02         74.6  11 st 10 lbs
# 14 2019-04-03         81.6  12 st 12 lbs
# 15 2019-04-04         79.1   12 st 6 lbs
# 16 2019-04-05         79.1   12 st 6 lbs
# 17 2019-04-06         76.7   12 st 1 lbs
# 18 2019-04-07         76.9   12 st 2 lbs
# 19 2019-04-08         76.2  11 st 14 lbs
# 20 2019-04-09          NaN            NaN
# 21 2019-04-10         75.7  11 st 13 lbs
# ...

# %%
HT = pandas.read_excel("C:\\Users\\local_4nmktoc\\Documents\\Alan_HT.xlsx", sheet_name = 1)
HT
# Out:
#          Date  Weight (kg) Stones & Pound  \
# 0  2019-03-20         77.8   12 st 4 lbs
# 1  2019-03-21         77.6   12 st 3 lbs
# 2  2019-03-22         76.7   12 st 1 lbs
# 3  2019-03-23          NaN            NaN
# 4  2019-03-24         77.6   12 st 3 lbs
# 5  2019-03-25         77.6   12 st 3 lbs
# 6  2019-03-26         76.8   12 st 1 lbs
# 7  2019-03-27         76.1  11 st 14 lbs
# 8  2019-03-28         76.4   12 st 0 lbs
# 9  2019-03-29         76.2  11 st 14 lbs
# 10 2019-03-30         77.6   12 st 3 lbs
# 11 2019-03-31          NaN            NaN
# 12 2019-04-01         76.6   12 st 1 lbs
# 13 2019-04-02         74.6  11 st 10 lbs
# 14 2019-04-03         81.6  12 st 12 lbs
# 15 2019-04-04         79.1   12 st 6 lbs
# 16 2019-04-05         79.1   12 st 6 lbs
# 17 2019-04-06         76.7   12 st 1 lbs
# 18 2019-04-07         76.9   12 st 2 lbs
# 19 2019-04-08         76.2  11 st 14 lbs
# 20 2019-04-09          NaN            NaN
# 21 2019-04-10         75.7  11 st 13 lbs
# ...

# %%
url = "https://en.wikipedia.org/wiki/Python_(programming_language)"

# %%
d = pandas.read_html(url)
d
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1                                            Paradigm
#  2                                         Designed by
#  3                                           Developer
#  4                                      First appeared
#  5                                                 NaN
#  6                                      Stable release
#  7                                   Typing discipline
#  8                                             License
#  9                                 Filename extensions
#  10                                            Website
#  11                              Major implementations
#  12  CPython, PyPy, Stackless Python, MicroPython. ...
#  13                                           Dialects
#  14                                    Cython, RPython
#  15                                      Influenced by
# ...

# %%
d = pandas.read_html(url)[1]
d
# Out:
#          Type    mutable                                        Description  \
# 0        bool  immutable                                      Boolean value
# 1   bytearray    mutable                                  Sequence of bytes
# 2       bytes  immutable                                  Sequence of bytes
# 3     complex  immutable       Complex number with real and imaginary parts
# 4        dict    mutable  Associative array (or dictionary) of key and v...
# 5    ellipsis        NaN  An ellipsis placeholder to be used as an index...
# 6       float  immutable    Floating point number, system-defined precision
# 7   frozenset  immutable  Unordered set, contains no duplicates; can con...
# 8         int  immutable                 Integer of unlimited magnitude[82]
# 9        list    mutable                      List, can contain mixed types
# 10        set    mutable  Unordered set, contains no duplicates; can con...
# ...

# %%
djson = pandas.read_json("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.json")
djson
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
djson.loc[5]
# Out:
# Address       6th Address, Miami
# Department                 Sales
# FirstName                   Anna
# ID                             6
# LastName                Sullivan
# Phone                 1234567895
# Salary                     54000
# Skills           In-Person Sales
# Name: 5, dtype: object

# %%
djson.loc[[2, 4, 7]]
# Out:
#               Address Department FirstName  ID LastName       Phone  Salary  \
# 2  3rd Address, Miami         IT       Ken   3     Wood  1234567892   58000
# 4  5th Address, Miami  Marketing     Emily   5   Larson  1234567894   60000
# 7  8th Address, Miami      Sales    Ronnie   8    Moore  1234567897   49000
#
#           Skills
# 2   Python, Java
# 4  Instagram Ads
# 7   Online Sales

# %%
djson.loc[3:5]
# Out:
#               Address Department FirstName  ID  LastName       Phone  Salary  \
# 3  4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4  5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5  6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
#
#             Skills
# 3     Facebook Ads
# 4    Instagram Ads
# 5  In-Person Sales

# %%
djson.loc[0:2,"Phone":"Skills"]
# Out:
#         Phone  Salary        Skills
# 0  1234567890   52000  Online Sales
# 1  1234567891   52200    Networking
# 2  1234567892   58000  Python, Java

# %%
HT.loc[0:67,"Date":"Issues"]
# Out:
#          Date  Weight (kg) Stones & Pound  \
# 0  2019-03-20         77.8   12 st 4 lbs
# 1  2019-03-21         77.6   12 st 3 lbs
# 2  2019-03-22         76.7   12 st 1 lbs
# 3  2019-03-23          NaN            NaN
# 4  2019-03-24         77.6   12 st 3 lbs
# 5  2019-03-25         77.6   12 st 3 lbs
# 6  2019-03-26         76.8   12 st 1 lbs
# 7  2019-03-27         76.1  11 st 14 lbs
# 8  2019-03-28         76.4   12 st 0 lbs
# 9  2019-03-29         76.2  11 st 14 lbs
# 10 2019-03-30         77.6   12 st 3 lbs
# 11 2019-03-31          NaN            NaN
# 12 2019-04-01         76.6   12 st 1 lbs
# 13 2019-04-02         74.6  11 st 10 lbs
# 14 2019-04-03         81.6  12 st 12 lbs
# 15 2019-04-04         79.1   12 st 6 lbs
# 16 2019-04-05         79.1   12 st 6 lbs
# 17 2019-04-06         76.7   12 st 1 lbs
# 18 2019-04-07         76.9   12 st 2 lbs
# 19 2019-04-08         76.2  11 st 14 lbs
# 20 2019-04-09          NaN            NaN
# 21 2019-04-10         75.7  11 st 13 lbs
# ...

# %%
djson.set_index("Address", inplace = True)

# %%
djson
# Out:
#                     Department FirstName  ID  LastName       Phone  Salary  \
# Address
# 1st Address, Miami       Sales      Luke   1   Phillip  1234567890   52000
# 2nd Address, Miami          IT      Jack   2    Darren  1234567891   52200
# 3rd Address, Miami          IT       Ken   3      Wood  1234567892   58000
# 4th Address, Miami   Marketing      John   4    Wilson  1234567893   58700
# 5th Address, Miami   Marketing     Emily   5    Larson  1234567894   60000
# 6th Address, Miami       Sales      Anna   6  Sullivan  1234567895   54000
# 7th Address, Miami   Logistics   Richard   7     Smith  1234567896   56000
# 8th Address, Miami       Sales    Ronnie   8     Moore  1234567897   49000
# 9th Address, Miami          IT       Ron   9     Drake  1234567898   53000
# 10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# ...

# %%
djson.loc["1st Address, Miami": "5th Address, Miami"]
# Out:
#                    Department FirstName  ID LastName       Phone  Salary  \
# Address
# 1st Address, Miami      Sales      Luke   1  Phillip  1234567890   52000
# 2nd Address, Miami         IT      Jack   2   Darren  1234567891   52200
# 3rd Address, Miami         IT       Ken   3     Wood  1234567892   58000
# 4th Address, Miami  Marketing      John   4   Wilson  1234567893   58700
# 5th Address, Miami  Marketing     Emily   5   Larson  1234567894   60000
#
#                            Skills
# Address
# 1st Address, Miami   Online Sales
# 2nd Address, Miami     Networking
# 3rd Address, Miami   Python, Java
# 4th Address, Miami   Facebook Ads
# 5th Address, Miami  Instagram Ads

# %%
djson.loc["1st Address, Miami": "5th Address, Miami", "Phone"]
# Out:
# Address
# 1st Address, Miami    1234567890
# 2nd Address, Miami    1234567891
# 3rd Address, Miami    1234567892
# 4th Address, Miami    1234567893
# 5th Address, Miami    1234567894
# Name: Phone, dtype: int64

# %%
djson.loc["1st Address, Miami": "5th Address, Miami", ["LastName", "Skills"]]
# Out:
#                    LastName         Skills
# Address
# 1st Address, Miami  Phillip   Online Sales
# 2nd Address, Miami   Darren     Networking
# 3rd Address, Miami     Wood   Python, Java
# 4th Address, Miami   Wilson   Facebook Ads
# 5th Address, Miami   Larson  Instagram Ads

# %%
djson.loc["1st Address, Miami": "5th Address, Miami", "LastName": "Skills"]
# Out:
#                    LastName       Phone  Salary         Skills
# Address
# 1st Address, Miami  Phillip  1234567890   52000   Online Sales
# 2nd Address, Miami   Darren  1234567891   52200     Networking
# 3rd Address, Miami     Wood  1234567892   58000   Python, Java
# 4th Address, Miami   Wilson  1234567893   58700   Facebook Ads
# 5th Address, Miami   Larson  1234567894   60000  Instagram Ads

# %%
HT = pandas.read_excel("C:\\Users\\local_4nmktoc\\Documents\\Alan_HT.xlsx")
HT
# Out:
#          Date  Weight (kg) Stones & Pound  \
# 0  2019-03-20         77.8   12 st 4 lbs
# 1  2019-03-21         77.6   12 st 3 lbs
# 2  2019-03-22         76.7   12 st 1 lbs
# 3  2019-03-23          NaN            NaN
# 4  2019-03-24         77.6   12 st 3 lbs
# 5  2019-03-25         77.6   12 st 3 lbs
# 6  2019-03-26         76.8   12 st 1 lbs
# 7  2019-03-27         76.1  11 st 14 lbs
# 8  2019-03-28         76.4   12 st 0 lbs
# 9  2019-03-29         76.2  11 st 14 lbs
# 10 2019-03-30         77.6   12 st 3 lbs
# 11 2019-03-31          NaN            NaN
# 12 2019-04-01         76.6   12 st 1 lbs
# 13 2019-04-02         74.6  11 st 10 lbs
# 14 2019-04-03         81.6  12 st 12 lbs
# 15 2019-04-04         79.1   12 st 6 lbs
# 16 2019-04-05         79.1   12 st 6 lbs
# 17 2019-04-06         76.7   12 st 1 lbs
# 18 2019-04-07         76.9   12 st 2 lbs
# 19 2019-04-08         76.2  11 st 14 lbs
# 20 2019-04-09          NaN            NaN
# 21 2019-04-10         75.7  11 st 13 lbs
# ...

# %%
djson.loc["1st Address, Miami", "Phone"]
# Out:
# 1234567890

# %%
djson.loc[:, "Phone"]
# Out:
# Address
# 1st Address, Miami     1234567890
# 2nd Address, Miami     1234567891
# 3rd Address, Miami     1234567892
# 4th Address, Miami     1234567893
# 5th Address, Miami     1234567894
# 6th Address, Miami     1234567895
# 7th Address, Miami     1234567896
# 8th Address, Miami     1234567897
# 9th Address, Miami     1234567898
# 10th Address, Miami    1234567899
# Name: Phone, dtype: int64

# %%
djson.loc[:, :]
# Out:
#                     Department FirstName  ID  LastName       Phone  Salary  \
# Address
# 1st Address, Miami       Sales      Luke   1   Phillip  1234567890   52000
# 2nd Address, Miami          IT      Jack   2    Darren  1234567891   52200
# 3rd Address, Miami          IT       Ken   3      Wood  1234567892   58000
# 4th Address, Miami   Marketing      John   4    Wilson  1234567893   58700
# 5th Address, Miami   Marketing     Emily   5    Larson  1234567894   60000
# 6th Address, Miami       Sales      Anna   6  Sullivan  1234567895   54000
# 7th Address, Miami   Logistics   Richard   7     Smith  1234567896   56000
# 8th Address, Miami       Sales    Ronnie   8     Moore  1234567897   49000
# 9th Address, Miami          IT       Ron   9     Drake  1234567898   53000
# 10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# ...

# %%
set(djson.loc[:, "Department"])
# Out:
# {'IT', 'Logistics', 'Marketing', 'Sales'}

# %%
djson.iloc[4]
# Out:
# Department        Marketing
# FirstName             Emily
# ID                        5
# LastName             Larson
# Phone            1234567894
# Salary                60000
# Skills        Instagram Ads
# Name: 5th Address, Miami, dtype: object

# %%
djson.iloc[[4, 6, 8]]
# Out:
#                    Department FirstName  ID LastName       Phone  Salary  \
# Address
# 5th Address, Miami  Marketing     Emily   5   Larson  1234567894   60000
# 7th Address, Miami  Logistics   Richard   7    Smith  1234567896   56000
# 9th Address, Miami         IT       Ron   9    Drake  1234567898   53000
#
#                              Skills
# Address
# 5th Address, Miami    Instagram Ads
# 7th Address, Miami  Warehouse Mgmt.
# 9th Address, Miami    Linux Servers

# %%
djson.iloc[2, 2:5]
# Out:
# ID                   3
# LastName          Wood
# Phone       1234567892
# Name: 3rd Address, Miami, dtype: object

# %%
djson
# Out:
#                     Department FirstName  ID  LastName       Phone  Salary  \
# Address
# 1st Address, Miami       Sales      Luke   1   Phillip  1234567890   52000
# 2nd Address, Miami          IT      Jack   2    Darren  1234567891   52200
# 3rd Address, Miami          IT       Ken   3      Wood  1234567892   58000
# 4th Address, Miami   Marketing      John   4    Wilson  1234567893   58700
# 5th Address, Miami   Marketing     Emily   5    Larson  1234567894   60000
# 6th Address, Miami       Sales      Anna   6  Sullivan  1234567895   54000
# 7th Address, Miami   Logistics   Richard   7     Smith  1234567896   56000
# 8th Address, Miami       Sales    Ronnie   8     Moore  1234567897   49000
# 9th Address, Miami          IT       Ron   9     Drake  1234567898   53000
# 10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# ...

# %%
djson = pandas.read_json("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.json")
djson
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
djson.iloc[2, 2:5]
# Out:
# FirstName     Ken
# ID              3
# LastName     Wood
# Name: 2, dtype: object

# %%
djson.iloc[:, 2:5]
# Out:
#   FirstName  ID  LastName
# 0      Luke   1   Phillip
# 1      Jack   2    Darren
# 2       Ken   3      Wood
# 3      John   4    Wilson
# 4     Emily   5    Larson
# 5      Anna   6  Sullivan
# 6   Richard   7     Smith
# 7    Ronnie   8     Moore
# 8       Ron   9     Drake
# 9     Wayne  10    Barker

# %%
djson.iloc[:]
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
djson.iloc[:, :]
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
djson.sample()
# Out:
#               Address Department FirstName  ID LastName       Phone  Salary  \
# 4  5th Address, Miami  Marketing     Emily   5   Larson  1234567894   60000
#
#           Skills
# 4  Instagram Ads

# %%
djson.sample()
# Out:
#               Address Department FirstName  ID LastName       Phone  Salary  \
# 2  3rd Address, Miami         IT       Ken   3     Wood  1234567892   58000
#
#          Skills
# 2  Python, Java

# %%
djson.sample(n = 4)
# Out:
#               Address Department FirstName  ID  LastName       Phone  Salary  \
# 3  4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 1  2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 4  5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5  6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
#
#             Skills
# 3     Facebook Ads
# 1       Networking
# 4    Instagram Ads
# 5  In-Person Sales

# %%
djson.sample(4)
# Out:
#                Address Department FirstName  ID LastName       Phone  Salary  \
# 9  10th Address, Miami  Logistics     Wayne  10   Barker  1234567899   59500
# 6   7th Address, Miami  Logistics   Richard   7    Smith  1234567896   56000
# 2   3rd Address, Miami         IT       Ken   3     Wood  1234567892   58000
# 0   1st Address, Miami      Sales      Luke   1  Phillip  1234567890   52000
#
#             Skills
# 9  Product Loading
# 6  Warehouse Mgmt.
# 2     Python, Java
# 0     Online Sales

# %%
djson.sample(frac = 0.5)
# Out:
#               Address Department FirstName  ID  LastName       Phone  Salary  \
# 4  5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 0  1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 2  3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 6  7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 5  6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
#
#             Skills
# 4    Instagram Ads
# 0     Online Sales
# 2     Python, Java
# 6  Warehouse Mgmt.
# 5  In-Person Sales

# %%
djson.sample(frac = 0.5)
# Out:
#               Address Department FirstName  ID  LastName       Phone  Salary  \
# 7  8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 1  2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 5  6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 2  3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 6  7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
#
#             Skills
# 7     Online Sales
# 1       Networking
# 5  In-Person Sales
# 2     Python, Java
# 6  Warehouse Mgmt.

# %%
djson.sample(frac = 0.3)
# Out:
#               Address Department FirstName  ID  LastName       Phone  Salary  \
# 5  6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 3  4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 6  7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
#
#             Skills
# 5  In-Person Sales
# 3     Facebook Ads
# 6  Warehouse Mgmt.

# %%
djson = pandas.read_json("C:\\Users\\local_4nmktoc\\Documents\\Coding\\Python\\Python_3_MasterClass\\Section 22 Automate Data Analysis\\Employee_Docs\\Employees.json")

# %%
djson.set_index("ID", inplace = True)

# %%
djson
# Out:
#                 Address Department FirstName  LastName       Phone  Salary  \
# ID
# 1    1st Address, Miami      Sales      Luke   Phillip  1234567890   52000
# 2    2nd Address, Miami         IT      Jack    Darren  1234567891   52200
# 3    3rd Address, Miami         IT       Ken      Wood  1234567892   58000
# 4    4th Address, Miami  Marketing      John    Wilson  1234567893   58700
# 5    5th Address, Miami  Marketing     Emily    Larson  1234567894   60000
# 6    6th Address, Miami      Sales      Anna  Sullivan  1234567895   54000
# 7    7th Address, Miami  Logistics   Richard     Smith  1234567896   56000
# 8    8th Address, Miami      Sales    Ronnie     Moore  1234567897   49000
# 9    9th Address, Miami         IT       Ron     Drake  1234567898   53000
# 10  10th Address, Miami  Logistics     Wayne    Barker  1234567899   59500
#
#              Skills
# ID
# 1      Online Sales
# 2        Networking
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# ...

# %%
djson[djson.loc[:, "Salary"] < 50000]
# Out:
#                Address Department FirstName LastName       Phone  Salary  \
# ID
# 8   8th Address, Miami      Sales    Ronnie    Moore  1234567897   49000
#
#           Skills
# ID
# 8   Online Sales

# %%
djson[(djson.loc[:, "Salary"] < 50000) | (djson.loc[:, "Salary"] > 56000)]
# Out:
#                 Address Department FirstName LastName       Phone  Salary  \
# ID
# 3    3rd Address, Miami         IT       Ken     Wood  1234567892   58000
# 4    4th Address, Miami  Marketing      John   Wilson  1234567893   58700
# 5    5th Address, Miami  Marketing     Emily   Larson  1234567894   60000
# 8    8th Address, Miami      Sales    Ronnie    Moore  1234567897   49000
# 10  10th Address, Miami  Logistics     Wayne   Barker  1234567899   59500
#
#              Skills
# ID
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# 8      Online Sales
# 10  Product Loading

# %%
djson[(djson.loc[:, "Salary"] > 50000) & (djson.loc[:, "Department"] == "Sales")]
# Out:
#                Address Department FirstName  LastName       Phone  Salary  \
# ID
# 1   1st Address, Miami      Sales      Luke   Phillip  1234567890   52000
# 6   6th Address, Miami      Sales      Anna  Sullivan  1234567895   54000
#
#              Skills
# ID
# 1      Online Sales
# 6   In-Person Sales

# %%
djson[~(djson.loc[:, "Department"] == "IT")]
# Out:
#                 Address Department FirstName  LastName       Phone  Salary  \
# ID
# 1    1st Address, Miami      Sales      Luke   Phillip  1234567890   52000
# 4    4th Address, Miami  Marketing      John    Wilson  1234567893   58700
# 5    5th Address, Miami  Marketing     Emily    Larson  1234567894   60000
# 6    6th Address, Miami      Sales      Anna  Sullivan  1234567895   54000
# 7    7th Address, Miami  Logistics   Richard     Smith  1234567896   56000
# 8    8th Address, Miami      Sales    Ronnie     Moore  1234567897   49000
# 10  10th Address, Miami  Logistics     Wayne    Barker  1234567899   59500
#
#              Skills
# ID
# 1      Online Sales
# 4      Facebook Ads
# 5     Instagram Ads
# 6   In-Person Sales
# 7   Warehouse Mgmt.
# 8      Online Sales
# 10  Product Loading
